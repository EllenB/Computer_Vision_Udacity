# %% [markdown]
# ## Import resources and display image

# %% [markdown]
# In this Ipython notebook, we learn to work with filters. Once such a filter is the Gaussian blur. One of the aims is to reduce speckle noise.
#
# As an example, we have taken a image of an ey from the following website where I wrote to get some code to play around with an image:
#
# https://www.pyimagesearch.com/2016/07/25/convolutions-with-opencv-and-python/
#
# For more information regarding smoothing of images, please see here:
#
# opencv-python-tutroals.readthedocs.io/en/latest/py_tutorials/py_imgproc/py_filtering/py_filtering.html#filtering

# %% [markdown]
# Reading in the libraries:

# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2

# %matplotlib inline

# %%
#image = cv2.imread('C:\\Ellen\\Udacity\\Computer_Vision\data\\Eye_Speckle.png')
image = cv2.imread('C:\\Ellen\\Udacity\\Computer_Vision\data\\3d_pokemon.png')
image.shape
# Out:
# (220L, 350L, 3L)

# %%
image_copy = np.copy(image)

# %% [markdown]
# Change to RGB:

# %%
image_copy = cv2.cvtColor(image_copy,cv2.COLOR_BGR2RGB)

# %%
plt.imshow(image_copy)

# %% [markdown]
# ## Gaussian blur the image

# %% [markdown]
# Convert the gray scale for filtering:

# %%
gray = cv2.cvtColor(image_copy,cv2.COLOR_RGB2GRAY)
plt.imshow(gray,cmap='gray')

# %%
gray_blur = cv2.GaussianBlur(gray,(5,5), 0 ) # 0 means that the standard deviation will automatically be computed.

plt.imshow(gray_blur,c)

# %% [markdown]
# A bigger filter will create a bigger blur.

# %% [markdown]
# Plot the images side by side:

# %%
f,(ax1,ax2) = plt.subplots(1,2,figsize = (20,10))

ax1.set_title('Original image')
ax1.imshow(gray,cmap='gray')
ax2.set_title('Blurred image')
ax2.imshow(gray_blur,cmap='gray')

# %%
image_copy2 = np.copy(image)
#plt.imshow(gray)
image_copy2 = cv2.cvtColor(image_copy2,cv2.COLOR_BGR2RGB)
plt.imshow(image_copy2)

# %%
blur2 = cv2.GaussianBlur(image_copy,(5,5), 0 ) # 0 means that the standard deviation will automatically be computed.

# %%
plt.imshow(blur2)

# %% [markdown]
# ## Test performance with a high pass filter

# %% [markdown]
# Now, 3 x 3 filter for edge detection:

# %%
sobel_x = np.array([[-2,0,2],
                  [-1,0,1],
                  [-2,0,2]])

# %%
filtered=cv2.filter2D(gray,-1,sobel_x)
filtered_blur=cv2.filter2D(gray,-1,sobel_x)

# %%
f,(ax1,ax2) = plt.subplots(1,2,figsize = (20,10))

ax1.set_title('Original image')
ax1.imshow(filtered,cmap='gray')
ax2.set_title('Blurred image')
ax2.imshow(filtered_blur,cmap='gray')

# %% [markdown]
# It can be the case that the blurred image has better edge detection.
