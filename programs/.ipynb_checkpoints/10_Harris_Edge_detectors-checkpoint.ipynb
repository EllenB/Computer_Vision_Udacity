# %% [markdown]
# https://www.youtube.com/watch?v=_qgKQGsuKeQ - The lectures are based on the book of Tzeleckis
#
# https://courses.edx.org/courses/course-v1:PennX+ROBO2x+2T2017/courseware/ - EdX course
#
# http://aishack.in/tutorials/features/ - Some more explanation on what features are.
#
# http://aishack.in/tutorials/harris-corner-detector/ - Some explanation of the Harris Corner detection itself.
#
# http://uhs.es/ComputerVisionPython.pdf - This codes the Harris corner detection from scratch and would illustrate the concept really well.

# %% [markdown]
# The following example is obtained from the following website:
# https://commons.wikimedia.org/wiki/File:Perspective_chessboard.png

# %% [markdown]
# Loading in the relevant packages:

# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt

% matplotlib inline

# %%
# Read in the image
image = cv2.imread('C:\\Ellen\\Udacity\\Computer_Vision\\data\\Perspective_chessboard.png')
print(image.shape)
# Out:
# (548, 767, 3)

# %%
# Make a copy of the image
image_copy = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# %%
# Change color to RGB
image_copy =cv2.cvtColor(image_copy,cv2.COLOR_BGR2RGB)

# %%
plt.imshow(image_copy)

# %% [markdown]
# ## Detect corners

# %%
gray = cv2.cvtColor(image_copy,cv2.COLOR_RGB2GRAY)

# %%
# Convert to float type
gray = np.float32(gray)

# %%
# Detect corners
dst = cv2.cornerHarris(gray, 2, 3, 0.04) # 2 means a 2 x 2 pixel square, 3 is the size of the Sobel operator
# 0.04 as to what is considered corners

# %%
plt.imshow(dst,cmap='gray')

# %% [markdown]
# It is hard to see, so we dilate it:

# %%
dst = cv2.dilate(dst, None)

# %%
plt.imshow(dst,cmap='gray')

# %% [markdown]
# ## Select and display the strongest corners

# %%
# Define a threshold for selecting strong corners
# This value may vary depending on the image

thresh = 0.01 * dst.max()

corner_image = np.copy(image_copy)

# Iterate through all the corners and draw them on the image (if they pass the threshold)
for j in range (0,dst.shape[0]):
    #print(j)
    for i in range(0,dst.shape[1]):
        #print(i)
        if(dst[j,i] > thresh):
        # image, center pt, radius, color, thickness
            cv2.circle(corner_image,(i,j), 2, (0,255,0), 1)
plt.imshow(corner_image)

# %% [markdown]
# ## Quiz: Corners for waffles

# %% [markdown]
# Read in the image:

# %%
image = cv2.imread('C:\\Ellen\\Udacity\\Computer_Vision\\data\\waffles_2.png')

# %%
image = cv2.cvtColor(image,cv2.COLOR_BGR2RGB)
plt.imshow(image)

# %%
## TODO: Complete this corner detection function
## This takes in an image
## And returns dilated corners
def corner_detect(image):
    # Convert the image to grayscale, floating point values
    gray = cv2.cvtColor(image, cv2.COLOR_RGB2GRAY)
    gray = np.float32(gray)
    
    ## TODO: Create a Harris corner detector using those grayscale vals
    ## Change this value, but keep the variable name
    corners = cv2.cornerHarris(gray, 2, 3, 0.04)
    
    ## TODO: Dilate the corner detections
    
    corners = cv2.dilate(corners, None)
    
    # Return those values
    return corners

# Runs your function (do not change this line of code)
corners = corner_detect(image)

## TODO: Define a threshold to select strong corners
threshold = 0.1 * corners.max()

if(corners is not None):
    # Create an image copy to draw corners on
    corner_image = np.copy(image)

    # Iterate through all the corners and draw them on the image (if they pass the threshold)
    for j in range(0, corners.shape[0]):
        for i in range(0, corners.shape[1]):
            if(corners[j,i] > threshold):
                # image, center pt, radius, color, thickness
                cv2.circle(corner_image, (i, j), 1, (0,255,0), 1)      
                
    # Plot the result
    f, (ax1, ax2) = plt.subplots(1, 2, figsize=(20, 10))
    f.tight_layout()
    ax1.imshow(corners, cmap='gray')
    ax1.set_title('Dilated Corners')
    ax2.imshow(corner_image, cmap='gray')
    ax2.set_title('Thresholded Corners')
